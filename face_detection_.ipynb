# %% [markdown]
# <a href="https://colab.research.google.com/github/sajad-naderzadeh/ML/blob/main/face_detection_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
from IPython.display import Image, display
import cv2
import numpy as np
from PIL import Image as PILImage
import io

uploaded = files.upload()

for filename in uploaded.keys():
    image = PILImage.open(io.BytesIO(uploaded[filename]))
    img = np.array(image)
    img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)  # چون تصویر RGB هست
# Out:
#      <input type="file" id="files-078fab8b-c24c-4543-aa8c-283ecb7ed9e8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-078fab8b-c24c-4543-aa8c-283ecb7ed9e8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# دانلود فایل haarcascade
# !wget -q https://github.com/opencv/opencv/raw/master/data/haarcascades/haarcascade_frontalface_default.xml

face_classifier = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

def detect_faces(img):
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_classifier.detectMultiScale(gray, 1.3, 5)

    if len(faces) == 0:
        print("چهره‌ای پیدا نشد.")
        return img

    for (x, y, w, h) in faces:
        cv2.rectangle(img, (x, y), (x + w, y + h), (0, 255, 0), 2)

    return img

# %%
from google.colab.patches import cv2_imshow

output_img = detect_faces(img)
cv2_imshow(output_img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=1000x798>
